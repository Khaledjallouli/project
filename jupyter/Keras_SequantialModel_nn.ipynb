# %% [markdown]
# <a href="https://colab.research.google.com/github/thu-soccer/project/blob/master/colab/colab_nn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
pd.set_option('display.max_columns', 999)

from sklearn import preprocessing
from sklearn.model_selection import train_test_split

import tensorflow as tf
from tensorflow_core.estimator import inputs
from tensorflow import feature_column
from tensorflow.keras import layers
from tensorflow.keras import regularizers
from tensorflow import keras
from tensorflow.keras.callbacks import EarlyStopping

from tensorflow.keras.models import load_model


import tensorflow_docs as tfdocs
import tensorflow_docs.modeling
import tensorflow_docs.plots

from  IPython import display
from matplotlib import pyplot as plt

import numpy as np
import math

import pathlib
import shutil
import tempfile


def normalize_and_encode(dataframe):
    column_names_to_not_normalize = ['result']
    column_names_to_normalize = [x for x in list(dataframe) if x not in column_names_to_not_normalize ]
    x = dataframe[column_names_to_normalize].values
    x_scaled = preprocessing.normalize(x)
    df_temp = pd.DataFrame(x_scaled, columns=column_names_to_normalize, index = dataframe.index)
    dataframe[column_names_to_normalize] = df_temp

    le = preprocessing.LabelEncoder()
    le.fit([ "H", "A", "D"])
    dataframe.loc[:,['result']]=le.transform(dataframe['result'])
    
    return dataframe

def get_X_and_y(dataframe):
    X = dataframe.drop(columns=['result']).values
    y = dataframe[['result']].values
    return X,y

df01 = pd.read_csv('../data/sliding01.csv', sep=',', index_col=0)
df02 = pd.read_csv('../data/sliding02_shots.csv', sep=',', index_col=0)
df03 = pd.read_csv('../data/sliding03_shots_extra.csv', sep=',', index_col=0)
df04 = pd.read_csv('../data/sliding04_shots_and_possession.csv', sep=',', index_col=0)
df05 = pd.read_csv('../data/sliding05_shots_and_possession_extra.csv', sep=',', index_col=0)

n01 = normalize_and_encode(df01)
n02 = normalize_and_encode(df02)
n03 = normalize_and_encode(df03)
n04 = normalize_and_encode(df04)
n05 = normalize_and_encode(df05)

train01, test01 = train_test_split(n01, test_size=0.05)
print(len(train01), 'train examples')
print(len(test01), 'test examples')

train02, test02 = train_test_split(n02, test_size=0.05)
print(len(train02), 'train examples')
print(len(test02), 'test examples')

train03, test03 = train_test_split(n03, test_size=0.05)
print(len(train03), 'train examples')
print(len(test03), 'test examples')

train04, test04 = train_test_split(n04, test_size=0.05)
print(len(train04), 'train examples')
print(len(test04), 'test examples')

train05, test05 = train_test_split(n05, test_size=0.05)
print(len(train04), 'train examples')
print(len(test04), 'test examples')

train_X01,train_y01 = get_X_and_y(train01)
train_X02,train_y02 = get_X_and_y(train02)
train_X03,train_y03 = get_X_and_y(train03)
train_X04,train_y04 = get_X_and_y(train04)
train_X05,train_y05 = get_X_and_y(train05)

test_X01,test_y01 = get_X_and_y(test01)
test_X02,test_y02 = get_X_and_y(test02)
test_X03,test_y03 = get_X_and_y(test03)
test_X04,test_y04 = get_X_and_y(test04)
test_X05,test_y05 = get_X_and_y(test05)


#Many models train better if you gradually reduce the learning rate during training. Use optimizers.schedules to reduce the learning rate over time:
#The code sets a schedules.InverseTimeDecay to hyperbolically decrease the learning rate to 1/2 of the base rate at 1000 epochs, 1/3 at 2000 epochs and so on.

def get_lr_schedule(train, batch_size):
    lr_schedule = tf.keras.optimizers.schedules.InverseTimeDecay(
    0.001,
    decay_steps=(len(train)//batch_size)*1000,
    decay_rate=1,
    staircase=False)
    return lr_schedule

def get_optimizer(train, batch_size):
    return tf.keras.optimizers.Adam(get_lr_schedule(train, batch_size))


#Each model in this tutorial will use the same training configuration. So set these up in a reusable way, starting with the list of callbacks.
#The training for this tutorial runs for many short epochs. To reduce the logging noise use the tfdocs.EpochDots which simply a . for each epoch and, and a full set of metrics every 100 epochs.

def get_callbacks(name):
    return [
        tfdocs.modeling.EpochDots(),
        tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=200),
        #tf.keras.callbacks.TensorBoard(logdir/name), # Jupyter Notebook
        #tf.keras.callbacks.TensorBoard(logdir, histogram_freq=1) # Google Colab
      ]

def compile_and_fit(model, name, X, y, validation_split, batch_size, optimizer=None, max_epochs=1000):
    if optimizer is None:
        optimizer = get_optimizer(X, batch_size)
    model.compile(optimizer=optimizer,
                loss='sparse_categorical_crossentropy',
                metrics=['accuracy','mse', 'mae', 'mape'])

    model.summary()
     
    history = model.fit(
        X,
        y,
        validation_split=validation_split,
        batch_size=batch_size,
#        steps_per_epoch = 50, # (len(train_X01)//batch_size,
        epochs=max_epochs,
        callbacks=get_callbacks(name),
        verbose=0)
    
    model.save("../model/%s.h5" %name) 
    
    return history

def plot_history(model_history):
	plt.plot(model_history.history['accuracy'])
	plt.plot(model_history.history['val_accuracy'])
	plt.title("%s accuracy" %model_history)
	plt.ylabel('accuracy')
	plt.xlabel('epoch')
	plt.legend(['train', 'val'], loc='upper left')
	plt.show()
	
	plt.plot(model_history.history['loss'])
	plt.plot(model_history.history['val_loss'])
	plt.title("%s loss" %model_history)
	plt.ylabel('loss')
	plt.xlabel('epoch')
	plt.legend(['train', 'val'], loc='upper left')
	plt.show()
# Out:
# 19781 train examples
# 1042 test examples
# 6681 train examples
# 352 test examples
# 6681 train examples
# 352 test examples
# 6646 train examples
# 350 test examples
# 6646 train examples
# 350 test examples

# %%
n01
# Out:
#        result  odds-home  odds-draw  odds-away  home-wins  home-draws  \
# 0           2   0.049957   0.165301   0.330601   0.183667    0.110200
# 1           1   0.077897   0.103862   0.121172   0.103862    0.138483
# 2           1   0.109311   0.117119   0.105407   0.195198    0.078079
# 3           0   0.068789   0.117049   0.155945   0.180075    0.108045
# 4           2   0.108097   0.154424   0.205899   0.102949    0.205899
# ...       ...        ...        ...        ...        ...         ...
# 20818       2   0.162536   0.123527   0.055262   0.097521    0.065014
# 20819       2   0.061498   0.110696   0.113771   0.092247    0.092247
# 20820       2   0.073697   0.153535   0.184242   0.122828    0.163770
# 20821       2   0.044350   0.175065   0.300111   0.066691    0.100037
# 20822       2   0.055791   0.140313   0.175391   0.200447    0.033408
#
#        home-losses  home-goals  home-opposition-goals  away-wins  away-draws  \
# 0         0.073467    0.514268               0.367334   0.073467    0.073467
# 1         0.103862    0.553931               0.415448   0.138483    0.103862
# 2         0.117119    0.390396               0.312317   0.156158    0.156158
# 3         0.072030    0.648271               0.396166   0.108045    0.108045
# 4         0.205899    0.308848               0.463272   0.051475    0.308848
# ...            ...         ...                    ...        ...         ...
# 20818     0.162536    0.260057               0.487607   0.065014    0.130029
# 20819     0.122995    0.307489               0.584228   0.030749    0.122995
# 20820     0.122828    0.409426               0.368484   0.204713    0.081885
# 20821     0.166729    0.400149               0.466840   0.100037    0.100037
# 20822     0.100223    0.334078               0.267263   0.133631    0.033408
#
#        away-losses  away-goals  away-opposition-goals
# 0         0.220401    0.293868               0.514268
# 1         0.103862    0.484690               0.415448
# 2         0.078079    0.585594               0.507514
# 3         0.144060    0.360151               0.396166
# 4         0.154424    0.360322               0.514746
# ...            ...         ...                    ...
# 20818     0.130029    0.325071               0.682650
# 20819     0.153744    0.215242               0.645726
# 20820     0.122828    0.614139               0.368484
# 20821     0.133383    0.366803               0.533532
# 20822     0.167039    0.467709               0.668156
#
# [20823 rows x 14 columns]

# %%
n02
# Out:
#       result  odds-home  odds-draw  odds-away  home-wins  home-draws  \
# 0          2   0
#
#       away-opposition_shots  away-opposition_shots_on_target  \
# 0                  0.256774                         0.106989
# 1                  0.321406                         0.132996
# 2                  0.376318                         0.173106
# 3                  0.357728                         0.183613
# 4                  0.455249                         0.234419
# ...                     ...                              ...
# 7028               0.454472                         0.263756
# 7029               0.313745                         0.129482
# 7030               0.499360                         0.236985
# 7031               0.483486                         0.214002
# 7032               0.415172                         0.180169
#
#       home_shot_accuracy  home_shot_efficiency  home_opposition_shot_accuracy  \
# 0               0.001744              0.000586                       0.001616
# 1               0.001764              0.000462                       0.001884
# 2               0.001819              0.000649                       0.001699
# 3               0.001467              0.000849                       0.001583
# 4               0.001519              0.000708                       0.001423
# ...                  ...                   ...                            ...
# 7028            0.002181              0.000944                       0.002081
# 7029            0.002630              0.000954                       0.002490
# 7030            0.002047              0.000574                       0.002300
# 7031            0.001981              0.000767                       0.002002
# 7032            0.002425              0.000603                       0.001679
#
#       home_opposition_shot_efficiency  away_shot_accuracy  \
# 0                            0.001077            0.001728
# 1                            0.000768            0.001563
# 2                            0.001008            0.001657
# 3                            0.001027            0.001780
# 4                            0.000877            0.001639
# ...                               ...                 ...
# 7028                         0.000812            0.001978
# 7029                         0.002274            0.002634
# 7030                         0.000677            0.002166
# 7031                         0.001110            0.002039
# 7032                         0.000580            0.002164
#
#       away_shot_efficiency  away_opposition_shot_accuracy  \
# 0                 0.000686                       0.001486
# 1                 0.000924                       0.001529
# 2                 0.000702                       0.001731
# 3                 0.000633                       0.001625
# 4                 0.000492                       0.001749
# ...                    ...                            ...
# 7028              0.000700                       0.002355
# 7029              0.000634                       0.002055
# 7030              0.001476                       0.002008
# 7031              0.000823                       0.001754
# 7032              0.000808                       0.001700
#
#       away_opposition_shot_efficiency
# 0                            0.000713
# 1                            0.001847
# 2                            0.001227
# 3                            0.000437
# 4                            0.000837
# ...                               ...
# 7028                         0.001311
# 7029                         0.004022
# 7030                         0.000680
# 7031                         0.001248
# 7032                         0.001618
#
# [7033 rows x 30 columns]

# %%
n04
# Out:
#       result  odds-home  odds-draw  odds-away  home-wins  home-draws  \
# 0          2   0.003670   0.003460   0.002202   0.001049    0.003146
# 1          2   0.003311   0.003311   0.002343   0.005094    0.002037
# 2          2   0.001254   0.006271   0.019859   0.007317    0.002090
# 3          0   0.002499   0.003465   0.003150   0.003150    0.003150
# 4          0   0.002715   0.003394   0.002924   0.004177    0.001044
# ...      ...        ...        ...        ...        ...         ...
# 6991       2   0.005271   0.004006   0.001792   0.004217    0.002108
# 6992       2   0.002133   0.003840   0.003946   0.003200    0.002133
# 6993       2   0.001912   0.003983   0.004780   0.003186    0.003186
# 6994       2   0.001399   0.005523   0.009468   0.002104    0.003156
# 6995       2   0.001752   0.004406   0.005508   0.006294    0.001049
#
#       home-losses  home-goals  home-opposition-goals  home-shots  \
# 0        0.006291    0.011534               0.016777    0.143652
# 1        0.003056    0.019356               0.012225    0.192540
# 2        0.001045    0.015678               0.008362    0.168280
# 3        0.004200    0.009449               0.011549    0.107092
# 4        0.005222    0.015665               0.016709    0.130540
# ...           ...         ...                    ...         ...
# 6991     0.004217    0.010541               0.012650    0.084331
# 6992     0.005333    0.009599               0.022398    0.094925
# Out:
#       result  odds-home  odds-draw  odds-away  home-wins  home-draws  \
# 0          2   0.003670   0.003460   0.002202   0.001049    0.003146
# 1          2   0.003311   0.003311   0.002343   0.005094    0.002037
# 2          2   0.001254   0.006271   0.019859   0.007317    0.002090
# 3          0   0.002499   0.003465   0.003150   0.003150    0.003150
# 4          0   0.002715   0.003394   0.002924   0.004177    0.001044
# ...      ...        ...        ...        ...        ...         ...
# 6991       2   0.005271   0.004006   0.001792   0.004217    0.002108
# 6992       2   0.002133   0.003840   0.003946   0.003200    0.002133
# 6993       2   0.001912   0.003983   0.004780   0.003186    0.003186
# 6994       2   0.001399   0.005523   0.009468   0.002104    0.003156
# 6995       2   0.001752   0.004406   0.005508   0.006294    0.001049
#
#       home-losses  home-goals  home-opposition-goals  home-shots  \
# 0        0.006291    0.011534               0.016777    0.143652
# 1        0.003056    0.019356               0.012225    0.192540
# 2        0.001045    0.015678               0.008362    0.168280
# 3        0.004200    0.009449               0.011549    0.107092
# 4        0.005222    0.015665               0.016709    0.130540
# ...           ...         ...                    ...         ...
# 6991     0.004217    0.010541               0.012650    0.084331
# 6992     0.005333    0.009599               0.022398    0.094925
# 6993     0.004249    0.008497               0.008497    0.129583
# 6994     0.005260    0.012624               0.014728    0.130447
# 6995     0.003147    0.010491               0.008393    0.110153
#
#       home-shots_on_target  home-possession  home-opposition_shots  \
# 0                 0.070253         0.504354               0.122681
# 1                 0.090667         0.550114               0.070292
# 2                 0.075255         0.498567               0.077346
# 3                 0.049346         0.460917               0.139640
# 4                 0.065792         0.454280               0.159781
# ...                    ...              ...                    ...
# 6991              0.045328         0.436415               0.123335
# 6992              0.050129         0.417030               0.098125
# 6993              0.062667         0.476909               0.097719
# 6994              0.065223         0.557555               0.104147
# 6995              0.068190         0.568600               0.132184
#
#       home-opposition_shots_on_target  home-opposition_possession  away-wins  \
# 0                            0.055573                    0.449829   0.008388
# 1                            0.036674                    0.375911   0.006112
# 2                            0.032402                    0.452578   0.002090
# 3                            0.080844                    0.494515   0.003150
# 4                            0.076236                    0.496053   0.004177
# ...                               ...                         ...        ...
# 6991                         0.063249                    0.521800   0.002108
# 6992                         0.049062                    0.553551   0.001067
# 6993                         0.053108                    0.489655   0.005311
# 6994                         0.052600                    0.399756   0.003156
# 6995                         0.056650                    0.386061   0.003147
#
#       away-draws  away-losses  away-goals  away-opposition-goals  away-shots  \
# 0       0.002097     0.000000    0.015728               0.006291    0.168817
# 1       0.003056     0.001019    0.019356               0.008150    0.172165
# 2       0.002090     0.006271    0.009407               0.018814    0.137968
# 3       0.002100     0.005250    0.009449               0.016799    0.121791
# 4       0.003133     0.003133    0.013576               0.016709    0.107565
# ...          ...          ...         ...                    ...         ...
# 6991    0.004217     0.004217    0.010541               0.022137    0.125443
# 6992    0.004266     0.005333    0.007466               0.022398    0.110923
# 6993    0.002124     0.003186    0.015932               0.009559    0.089221
# 6994    0.003156     0.004208    0.011572               0.017884    0.108355
# 6995    0.002098     0.005245    0.013638               0.019932    0.119595
#
#       away-shots_on_target  away-possession  away-opposition_shots  \
# 0                 0.081787         0.505402               0.075496
# 1                 0.096779         0.558263               0.115116
# 2                 0.064803         0.443171               0.145285
# 3                 0.056696         0.430469               0.137540
# 4                 0.053260         0.456369               0.144117
# ...                    ...              ...                    ...
# 6991              0.061140         0.410061               0.118064
# 6992              0.058661         0.447960               0.067194
# 6993              0.045673         0.525769               0.125335
# 6994              0.055755         0.460772               0.128343
# 6995              0.066092         0.487821               0.111202
#
#       away-opposition_shots_on_target  away-opposition_possession  \
# 0                            0.031457                    0.448780
# 1                            0.059086                    0.368780
# 2                            0.074210                    0.507974
# 3                            0.067195                    0.524962
# 4                            0.079369                    0.493965
# ...                               ...                         ...
# 6991                         0.068519                    0.549208
# 6992                         0.027731                    0.522620
# 6993                         0.059481                    0.439734
# 6994                         0.056807                    0.496539
# 6995                         0.048258                    0.466840
#
#       home_shot_accuracy  home_shot_efficiency  home_opposition_shot_accuracy  \
# 0               0.000513              0.000172                       0.000475
# 1               0.000480              0.000217                       0.000532
# 2               0.000467              0.000218                       0.000438
# 3               0.000484              0.000201                       0.000608
# 4               0.000526              0.000249                       0.000498
# ...                  ...                   ...                            ...
# 6991            0.000567              0.000245                       0.000541
# 6992            0.000563              0.000204                       0.000533
# 6993            0.000514              0.000144                       0.000577
# 6994            0.000526              0.000204                       0.000531
# 6995            0.000649              0.000161                       0.000450
#
#       home_opposition_shot_efficiency  away_shot_accuracy  \
# 0                            0.000317            0.000508
# 1                            0.000340            0.000573
# 2                            0.000270            0.000491
# 3                            0.000150            0.000489
# 4                            0.000229            0.000517
# ...                               ...                 ...
# 6991                         0.000211            0.000514
# 6992                         0.000487            0.000564
# 6993                         0.000170            0.000544
# 6994                         0.000295            0.000541
# 6995                         0.000155            0.000580
#
#       away_shot_efficiency  away_opposition_shot_accuracy  \
# 0                 0.000202                       0.000437
# 1                 0.000204                       0.000523
# 2                 0.000152                       0.000534
# 3                 0.000175                       0.000513
# 4                 0.000266                       0.000575
# ...                    ...                            ...
# 6991              0.000182                       0.000612
# 6992              0.000136                       0.000440
# 6993              0.000371                       0.000504
# 6994              0.000218                       0.000466
# 6995              0.000216                       0.000455
#
#       away_opposition_shot_efficiency
# 0                            0.000210
# 1                            0.000141
# 2                            0.000265
# 3                            0.000262
# 4                            0.000220
# ...                               ...
# 6991                         0.000341
# 6992                         0.000861
# 6993                         0.000171
# 6994                         0.000331
# 6995                         0.000433
#
# [6996 rows x 34 columns]

# %% [markdown]
# <hr>

# %%
# Jupyter notebook
logdir = pathlib.Path(tempfile.mkdtemp())/"tensorboard_logs"
shutil.rmtree(logdir, ignore_errors=True)


BATCH_SIZE = 128*8
EPOCHS=10000
validation_split = 0.2
size_histories = {}

model01 = tf.keras.Sequential([
  layers.Dense(13, activation='relu',input_shape=(train_X01.shape[1],)), # 13 features
  layers.Dense(11, activation='relu'),
  layers.Dense(9, activation='relu'),
  layers.Dense(7, activation='relu'),
  layers.Dense(5, activation='relu'),
  layers.Dense(3, activation='softmax')
])

model02 = tf.keras.Sequential([
  layers.Dense(21, activation='relu',input_shape=(train_X02.shape[1],)), # 21 features
  layers.Dense(80, activation='relu'),
  layers.Dense(40, activation='relu'),
  layers.Dense(20, activation='relu'),
  layers.Dense(10, activation='relu'),
  layers.Dense(3, activation='softmax')
])

model03 = tf.keras.Sequential([
  layers.Dense(29, activation='relu',input_shape=(train_X03.shape[1],)), # 29 features
  layers.Dense(29, activation='relu'),
  layers.Dense(20, activation='relu'),
  layers.Dense(10, activation='relu'),
  layers.Dense(5, activation='relu'),
  layers.Dense(3, activation='softmax')
])

model04 = tf.keras.Sequential([
  layers.Dense(25, activation='relu',input_shape=(train_X04.shape[1],)), # 25 features
  layers.Dense(50, activation='relu'),
  layers.Dense(30, activation='relu'),
  layers.Dense(10, activation='relu'),
  layers.Dense(8, activation='relu'),
  layers.Dense(3, activation='softmax')
])

model05 = tf.keras.Sequential([
  layers.Dense(33, activation='relu',input_shape=(train_X05.shape[1],)), # 33 features
  layers.Dense(66, activation='relu'),
  layers.Dense(55, activation='relu'),
  layers.Dense(44, activation='relu'),
  layers.Dense(33, activation='relu'),
  layers.Dense(22, activation='relu'),
  layers.Dense(11, activation='relu'),
  layers.Dense(8, activation='relu'),
  layers.Dense(3, activation='softmax')
])

size_histories['model01'] = compile_and_fit(model01, 'martin_model01', train_X01, train_y01, validation_split=validation_split,batch_size=BATCH_SIZE,max_epochs=EPOCHS)
size_histories['model02'] = compile_and_fit(model02, 'martin_model02', train_X02, train_y02, validation_split=validation_split,batch_size=BATCH_SIZE,max_epochs=EPOCHS)
size_histories['model03'] = compile_and_fit(model03, 'martin_model03', train_X03, train_y03, validation_split=validation_split,batch_size=BATCH_SIZE,max_epochs=EPOCHS)
size_histories['model04'] = compile_and_fit(model04, 'martin_model04', train_X04, train_y04, validation_split=validation_split,batch_size=BATCH_SIZE,max_epochs=EPOCHS)
size_histories['model05'] = compile_and_fit(model05, 'martin_model05', train_X05, train_y05, validation_split=validation_split,batch_size=BATCH_SIZE,max_epochs=EPOCHS)
# Out:
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_66 (Dense)             (None, 13)                182
# _________________________________________________________________
# dense_67 (Dense)             (None, 11)                154
# _________________________________________________________________
# dense_68 (Dense)             (None, 9)                 108
# _________________________________________________________________
# dense_69 (Dense)             (None, 7)                 70
# _________________________________________________________________
# dense_70 (Dense)             (None, 5)                 40
# _________________________________________________________________
# dense_71 (Dense)             (None, 3)                 18
# =================================================================
# Total params: 572
# Trainable params: 572
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch: 0, acc:0.2899,  loss:1.0997,  mean_absolute_error:1.0307,  mean_absolute_percentage_error:95487832.0000,  mean_squared_error:1.4213,  val_acc:0.4559,  val_loss:1.0937,  val_mean_absolute_error:1.0291,  val_mean_absolute_percentage_error:97295896.0000,  val_mean_squared_error:1.4198,
# ....................................................................................................
# Epoch: 100, acc:0.5326,  loss:0.9716,  mean_absolute_error:1.0307,  mean_absolute_percentage_error:95487832.0000,  mean_squared_error:1.4510,  val_acc:0.5322,  val_loss:0.9765,  val_mean_absolute_error:1.0291,  val_mean_absolute_percentage_error:97295896.0000,  val_mean_squared_error:1.4498,
# ....................................................................................................
# Epoch: 200, acc:0.5314,  loss:0.9705,  mean_absolute_error:1.0307,  mean_absolute_percentage_error:95487816.0000,  mean_squared_error:1.4506,  val_acc:0.5251,  val_loss:0.9789,  val_mean_absolute_error:1.0291,  val_mean_absolute_percentage_error:97295904.0000,  val_mean_squared_error:1.4535,
# ....................................................................................................
# Epoch: 300, acc:0.5325,  loss:0.9692,  mean_absolute_error:1.0307,  mean_absolute_percentage_error:95487824.0000,  mean_squared_error:1.4516,  val_acc:0.5262,  val_loss:0.9772,  val_mean_absolute_error:1.0291,  val_mean_absolute_percentage_error:97295896.0000,  val_mean_squared_error:1.4491,
# ....................................................................................................
# Epoch: 400, acc:0.5332,  loss:0.9685,  mean_absolute_error:1.0307,  mean_absolute_percentage_error:95487832.0000,  mean_squared_error:1.4515,  val_acc:0.5302,  val_loss:0.9763,  val_mean_absolute_error:1.0291,  val_mean_absolute_percentage_error:97295896.0000,  val_mean_squared_error:1.4489,
# ....................................................................................Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_72 (Dense)             (None, 21)                462
# _________________________________________________________________
# dense_73 (Dense)             (None, 80)                1760
# _________________________________________________________________
# dense_74 (Dense)             (None, 40)                3240
# _________________________________________________________________
# dense_75 (Dense)             (None, 20)                820
# _________________________________________________________________
# dense_76 (Dense)             (None, 10)                210
# _________________________________________________________________
# dense_77 (Dense)             (None, 3)                 33
# =================================================================
# Total params: 6,525
# Trainable params: 6,525
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch: 0, acc:0.4601,  loss:1.0847,  mean_absolute_error:1.0304,  mean_absolute_percentage_error:96432096.0000,  mean_squared_error:1.4223,  val_acc:0.4630,  val_loss:1.0740,  val_mean_absolute_error:1.0324,  val_mean_absolute_percentage_error:97232584.0000,  val_mean_squared_error:1.4292,
# ....................................................................................................
# Epoch: 100, acc:0.5281,  loss:0.9722,  mean_absolute_error:1.0304,  mean_absolute_percentage_error:96432088.0000,  mean_squared_error:1.4506,  val_acc:0.5243,  val_loss:0.9884,  val_mean_absolute_error:1.0324,  val_mean_absolute_percentage_error:97232592.0000,  val_mean_squared_error:1.4565,
# ....................................................................................................
# Epoch: 200, acc:0.5365,  loss:0.9607,  mean_absolute_error:1.0304,  mean_absolute_percentage_error:96432104.0000,  mean_squared_error:1.4527,  val_acc:0.5318,  val_loss:0.9870,  val_mean_absolute_error:1.0324,  val_mean_absolute_percentage_error:97232584.0000,  val_mean_squared_error:1.4581,
# ....................................................................................................
# Epoch: 300, acc:0.5397,  loss:0.9550,  mean_absolute_error:1.0304,  mean_absolute_percentage_error:96432088.0000,  mean_squared_error:1.4549,  val_acc:0.5266,  val_loss:0.9853,  val_mean_absolute_error:1.0324,  val_mean_absolute_percentage_error:97232592.0000,  val_mean_squared_error:1.4602,
# ....................................................................................................
# Epoch: 400, acc:0.5402,  loss:0.9558,  mean_absolute_error:1.0304,  mean_absolute_percentage_error:96432088.0000,  mean_squared_error:1.4530,  val_acc:0.5333,  val_loss:0.9855,  val_mean_absolute_error:1.0324,  val_mean_absolute_percentage_error:97232584.0000,  val_mean_squared_error:1.4596,
# ................................................Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_78 (Dense)             (None, 29)                870
# _________________________________________________________________
# dense_79 (Dense)             (None, 29)                870
# _________________________________________________________________
# dense_80 (Dense)             (None, 20)                600
# _________________________________________________________________
# dense_81 (Dense)             (None, 10)                210
# _________________________________________________________________
# dense_82 (Dense)             (None, 5)                 55
# _________________________________________________________________
# dense_83 (Dense)             (None, 3)                 18
# =================================================================
# Total params: 2,623
# Trainable params: 2,623
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch: 0, acc:0.4525,  loss:1.0922,  mean_absolute_error:1.0280,  mean_absolute_percentage_error:98240968.0000,  mean_squared_error:1.4186,  val_acc:0.4667,  val_loss:1.0873,  val_mean_absolute_error:1.0439,  val_mean_absolute_percentage_error:89503848.0000,  val_mean_squared_error:1.4442,
# ....................................................................................................
# Epoch: 100, acc:0.5245,  loss:0.9776,  mean_absolute_error:1.0280,  mean_absolute_percentage_error:98240968.0000,  mean_squared_error:1.4435,  val_acc:0.5393,  val_loss:0.9784,  val_mean_absolute_error:1.0439,  val_mean_absolute_percentage_error:89503840.0000,  val_mean_squared_error:1.4720,
# ....................................................................................................
# Epoch: 200, acc:0.5342,  loss:0.9706,  mean_absolute_error:1.0280,  mean_absolute_percentage_error:98240968.0000,  mean_squared_error:1.4499,  val_acc:0.5370,  val_loss:0.9756,  val_mean_absolute_error:1.0439,  val_mean_absolute_percentage_error:89503872.0000,  val_mean_squared_error:1.4735,
# ....................................................................................................
# Epoch: 300, acc:0.5361,  loss:0.9677,  mean_absolute_error:1.0280,  mean_absolute_percentage_error:98240968.0000,  mean_squared_error:1.4471,  val_acc:0.5408,  val_loss:0.9701,  val_mean_absolute_error:1.0439,  val_mean_absolute_percentage_error:89503856.0000,  val_mean_squared_error:1.4780,
# ....................................................................................................
# Epoch: 400, acc:0.5395,  loss:0.9634,  mean_absolute_error:1.0280,  mean_absolute_percentage_error:98240976.0000,  mean_squared_error:1.4497,  val_acc:0.5378,  val_loss:0.9706,  val_mean_absolute_error:1.0439,  val_mean_absolute_percentage_error:89503864.0000,  val_mean_squared_error:1.4744,
# ....................................................................................................
# Epoch: 500, acc:0.5402,  loss:0.9619,  mean_absolute_error:1.0280,  mean_absolute_percentage_error:98240968.0000,  mean_squared_error:1.4489,  val_acc:0.5438,  val_loss:0.9673,  val_mean_absolute_error:1.0439,  val_mean_absolute_percentage_error:89503840.0000,  val_mean_squared_error:1.4768,
# ....................................................................................................
# Epoch: 600, acc:0.5399,  loss:0.9613,  mean_absolute_error:1.0280,  mean_absolute_percentage_error:98240976.0000,  mean_squared_error:1.4512,  val_acc:0.5385,  val_loss:0.9698,  val_mean_absolute_error:1.0439,  val_mean_absolute_percentage_error:89503840.0000,  val_mean_squared_error:1.4753,
# ................................................................Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_84 (Dense)             (None, 25)                650
# _________________________________________________________________
# dense_85 (Dense)             (None, 50)                1300
# _________________________________________________________________
# dense_86 (Dense)             (None, 30)                1530
# _________________________________________________________________
# dense_87 (Dense)             (None, 10)                310
# _________________________________________________________________
# dense_88 (Dense)             (None, 8)                 88
# _________________________________________________________________
# dense_89 (Dense)             (None, 3)                 27
# =================================================================
# Total params: 3,905
# Trainable params: 3,905
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch: 0, acc:0.4673,  loss:1.0681,  mean_absolute_error:1.0375,  mean_absolute_percentage_error:96438384.0000,  mean_squared_error:1.4405,  val_acc:0.4556,  val_loss:1.0655,  val_mean_absolute_error:1.0288,  val_mean_absolute_percentage_error:93483688.0000,  val_mean_squared_error:1.4198,
# ....................................................................................................
# Epoch: 100, acc:0.5265,  loss:0.9797,  mean_absolute_error:1.0375,  mean_absolute_percentage_error:96438392.0000,  mean_squared_error:1.4642,  val_acc:0.5038,  val_loss:1.0053,  val_mean_absolute_error:1.0288,  val_mean_absolute_percentage_error:93483688.0000,  val_mean_squared_error:1.4405,
# ....................................................................................................
# Epoch: 200, acc:0.5324,  loss:0.9736,  mean_absolute_error:1.0375,  mean_absolute_percentage_error:96438384.0000,  mean_squared_error:1.4709,  val_acc:0.5165,  val_loss:1.0004,  val_mean_absolute_error:1.0288,  val_mean_absolute_percentage_error:93483688.0000,  val_mean_squared_error:1.4392,
# ....................................................................................................
# Epoch: 300, acc:0.5348,  loss:0.9685,  mean_absolute_error:1.0375,  mean_absolute_percentage_error:96438384.0000,  mean_squared_error:1.4676,  val_acc:0.5083,  val_loss:0.9919,  val_mean_absolute_error:1.0288,  val_mean_absolute_percentage_error:93483704.0000,  val_mean_squared_error:1.4456,
# ....................................................................................................
# Epoch: 400, acc:0.5421,  loss:0.9629,  mean_absolute_error:1.0375,  mean_absolute_percentage_error:96438384.0000,  mean_squared_error:1.4695,  val_acc:0.5098,  val_loss:0.9892,  val_mean_absolute_error:1.0288,  val_mean_absolute_percentage_error:93483688.0000,  val_mean_squared_error:1.4465,
# ....................................................................................................
# Epoch: 500, acc:0.5442,  loss:0.9611,  mean_absolute_error:1.0375,  mean_absolute_percentage_error:96438384.0000,  mean_squared_error:1.4721,  val_acc:0.5180,  val_loss:0.9861,  val_mean_absolute_error:1.0288,  val_mean_absolute_percentage_error:93483688.0000,  val_mean_squared_error:1.4449,
# ....................................................................................................
# Epoch: 600, acc:0.5435,  loss:0.9597,  mean_absolute_error:1.0375,  mean_absolute_percentage_error:96438384.0000,  mean_squared_error:1.4706,  val_acc:0.5158,  val_loss:0.9832,  val_mean_absolute_error:1.0288,  val_mean_absolute_percentage_error:93483688.0000,  val_mean_squared_error:1.4448,
# ....................................................................................................
# Epoch: 700, acc:0.5433,  loss:0.9598,  mean_absolute_error:1.0375,  mean_absolute_percentage_error:96438376.0000,  mean_squared_error:1.4692,  val_acc:0.5128,  val_loss:0.9844,  val_mean_absolute_error:1.0288,  val_mean_absolute_percentage_error:93483680.0000,  val_mean_squared_error:1.4481,
# ....................................................................................................
# Epoch: 800, acc:0.5482,  loss:0.9571,  mean_absolute_error:1.0375,  mean_absolute_percentage_error:96438384.0000,  mean_squared_error:1.4708,  val_acc:0.5150,  val_loss:0.9824,  val_mean_absolute_error:1.0288,  val_mean_absolute_percentage_error:93483688.0000,  val_mean_squared_error:1.4482,
# ....................................................................................................
# Epoch: 900, acc:0.5427,  loss:0.9572,  mean_absolute_error:1.0375,  mean_absolute_percentage_error:96438384.0000,  mean_squared_error:1.4714,  val_acc:0.5135,  val_loss:0.9810,  val_mean_absolute_error:1.0288,  val_mean_absolute_percentage_error:93483704.0000,  val_mean_squared_error:1.4426,
# ....................................................................................................
# Epoch: 1000, acc:0.5476,  loss:0.9554,  mean_absolute_error:1.0375,  mean_absolute_percentage_error:96438384.0000,  mean_squared_error:1.4706,  val_acc:0.5165,  val_loss:0.9801,  val_mean_absolute_error:1.0288,  val_mean_absolute_percentage_error:93483688.0000,  val_mean_squared_error:1.4454,
# ....................................................................................................
# Epoch: 1100, acc:0.5483,  loss:0.9549,  mean_absolute_error:1.0375,  mean_absolute_percentage_error:96438384.0000,  mean_squared_error:1.4700,  val_acc:0.5180,  val_loss:0.9790,  val_mean_absolute_error:1.0288,  val_mean_absolute_percentage_error:93483688.0000,  val_mean_squared_error:1.4466,
# ....................................................................................................
# Epoch: 1200, acc:0.5467,  loss:0.9568,  mean_absolute_error:1.0375,  mean_absolute_percentage_error:96438384.0000,  mean_squared_error:1.4697,  val_acc:0.5195,  val_loss:0.9793,  val_mean_absolute_error:1.0288,  val_mean_absolute_percentage_error:93483688.0000,  val_mean_squared_error:1.4472,
# ....................................................................................................
# Epoch: 1300, acc:0.5485,  loss:0.9543,  mean_absolute_error:1.0375,  mean_absolute_percentage_error:96438384.0000,  mean_squared_error:1.4692,  val_acc:0.5158,  val_loss:0.9771,  val_mean_absolute_error:1.0288,  val_mean_absolute_percentage_error:93483696.0000,  val_mean_squared_error:1.4450,
# ....................................................................................................
# Epoch: 1400, acc:0.5487,  loss:0.9542,  mean_absolute_error:1.0375,  mean_absolute_percentage_error:96438384.0000,  mean_squared_error:1.4718,  val_acc:0.5188,  val_loss:0.9786,  val_mean_absolute_error:1.0288,  val_mean_absolute_percentage_error:93483688.0000,  val_mean_squared_error:1.4470,
# ....................................................................................................
# Epoch: 1500, acc:0.5442,  loss:0.9547,  mean_absolute_error:1.0375,  mean_absolute_percentage_error:96438384.0000,  mean_squared_error:1.4733,  val_acc:0.5128,  val_loss:0.9785,  val_mean_absolute_error:1.0288,  val_mean_absolute_percentage_error:93483688.0000,  val_mean_squared_error:1.4451,
# ....................................................................................................
# Epoch: 1600, acc:0.5502,  loss:0.9537,  mean_absolute_error:1.0375,  mean_absolute_percentage_error:96438384.0000,  mean_squared_error:1.4723,  val_acc:0.5203,  val_loss:0.9791,  val_mean_absolute_error:1.0288,  val_mean_absolute_percentage_error:93483688.0000,  val_mean_squared_error:1.4483,
# ....................................................................................................
# Epoch: 1700, acc:0.5431,  loss:0.9546,  mean_absolute_error:1.0375,  mean_absolute_percentage_error:96438384.0000,  mean_squared_error:1.4739,  val_acc:0.5128,  val_loss:0.9774,  val_mean_absolute_error:1.0288,  val_mean_absolute_percentage_error:93483688.0000,  val_mean_squared_error:1.4453,
# ....................................................................................................
# Epoch: 1800, acc:0.5489,  loss:0.9528,  mean_absolute_error:1.0375,  mean_absolute_percentage_error:96438384.0000,  mean_squared_error:1.4712,  val_acc:0.5218,  val_loss:0.9797,  val_mean_absolute_error:1.0288,  val_mean_absolute_percentage_error:93483688.0000,  val_mean_squared_error:1.4487,
# ....................................................................................................
# Epoch: 1900, acc:0.5485,  loss:0.9534,  mean_absolute_error:1.0375,  mean_absolute_percentage_error:96438384.0000,  mean_squared_error:1.4697,  val_acc:0.5203,  val_loss:0.9789,  val_mean_absolute_error:1.0288,  val_mean_absolute_percentage_error:93483688.0000,  val_mean_squared_error:1.4481,
# .........Model: "sequential_14"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_90 (Dense)             (None, 33)                1122
# _________________________________________________________________
# dense_91 (Dense)             (None, 66)                2244
# _________________________________________________________________
# dense_92 (Dense)             (None, 55)                3685
# _________________________________________________________________
# dense_93 (Dense)             (None, 44)                2464
# _________________________________________________________________
# dense_94 (Dense)             (None, 33)                1485
# _________________________________________________________________
# dense_95 (Dense)             (None, 22)                748
# _________________________________________________________________
# dense_96 (Dense)             (None, 11)                253
# _________________________________________________________________
# dense_97 (Dense)             (None, 8)                 96
# _________________________________________________________________
# dense_98 (Dense)             (None, 3)                 27
# =================================================================
# Total params: 12,124
# Trainable params: 12,124
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch: 0, acc:0.4626,  loss:1.0934,  mean_absolute_error:1.0342,  mean_absolute_percentage_error:95058904.0000,  mean_squared_error:1.4288,  val_acc:0.4579,  val_loss:1.0886,  val_mean_absolute_error:1.0271,  val_mean_absolute_percentage_error:97493704.0000,  val_mean_squared_error:1.4159,
# ....................................................................................................
# Epoch: 100, acc:0.5282,  loss:0.9756,  mean_absolute_error:1.0342,  mean_absolute_percentage_error:95058904.0000,  mean_squared_error:1.4542,  val_acc:0.5211,  val_loss:1.0003,  val_mean_absolute_error:1.0271,  val_mean_absolute_percentage_error:97493704.0000,  val_mean_squared_error:1.4466,
# ....................................................................................................
# Epoch: 200, acc:0.5303,  loss:0.9728,  mean_absolute_error:1.0342,  mean_absolute_percentage_error:95058904.0000,  mean_squared_error:1.4621,  val_acc:0.5105,  val_loss:0.9956,  val_mean_absolute_error:1.0271,  val_mean_absolute_percentage_error:97493712.0000,  val_mean_squared_error:1.4421,
# ....................................................................................................
# Epoch: 300, acc:0.5359,  loss:0.9635,  mean_absolute_error:1.0342,  mean_absolute_percentage_error:95058904.0000,  mean_squared_error:1.4624,  val_acc:0.5218,  val_loss:0.9869,  val_mean_absolute_error:1.0271,  val_mean_absolute_percentage_error:97493704.0000,  val_mean_squared_error:1.4486,
# ....................................................................................................
# Epoch: 400, acc:0.5380,  loss:0.9651,  mean_absolute_error:1.0342,  mean_absolute_percentage_error:95058912.0000,  mean_squared_error:1.4583,  val_acc:0.5195,  val_loss:0.9844,  val_mean_absolute_error:1.0271,  val_mean_absolute_percentage_error:97493704.0000,  val_mean_squared_error:1.4467,
# ....................................................................................................
# Epoch: 500, acc:0.5408,  loss:0.9582,  mean_absolute_error:1.0342,  mean_absolute_percentage_error:95058904.0000,  mean_squared_error:1.4610,  val_acc:0.5180,  val_loss:0.9833,  val_mean_absolute_error:1.0271,  val_mean_absolute_percentage_error:97493720.0000,  val_mean_squared_error:1.4481,
# ....................................................................................................
# Epoch: 600, acc:0.5408,  loss:0.9584,  mean_absolute_error:1.0342,  mean_absolute_percentage_error:95058904.0000,  mean_squared_error:1.4630,  val_acc:0.5211,  val_loss:0.9861,  val_mean_absolute_error:1.0271,  val_mean_absolute_percentage_error:97493696.0000,  val_mean_squared_error:1.4461,
# ....................................................................................................
# Epoch: 700, acc:0.5436,  loss:0.9545,  mean_absolute_error:1.0342,  mean_absolute_percentage_error:95058904.0000,  mean_squared_error:1.4635,  val_acc:0.5188,  val_loss:0.9841,  val_mean_absolute_error:1.0271,  val_mean_absolute_percentage_error:97493704.0000,  val_mean_squared_error:1.4517,
# ....................................................................................................
# Epoch: 800, acc:0.5461,  loss:0.9529,  mean_absolute_error:1.0342,  mean_absolute_percentage_error:95058904.0000,  mean_squared_error:1.4605,  val_acc:0.5180,  val_loss:0.9826,  val_mean_absolute_error:1.0271,  val_mean_absolute_percentage_error:97493704.0000,  val_mean_squared_error:1.4490,
# ....................................................................................................
# Epoch: 900, acc:0.5478,  loss:0.9509,  mean_absolute_error:1.0342,  mean_absolute_percentage_error:95058904.0000,  mean_squared_error:1.4616,  val_acc:0.5173,  val_loss:0.9827,  val_mean_absolute_error:1.0271,  val_mean_absolute_percentage_error:97493704.0000,  val_mean_squared_error:1.4476,
# ....................................................................................................
# Epoch: 1000, acc:0.5451,  loss:0.9494,  mean_absolute_error:1.0342,  mean_absolute_percentage_error:95058904.0000,  mean_squared_error:1.4620,  val_acc:0.5188,  val_loss:0.9852,  val_mean_absolute_error:1.0271,  val_mean_absolute_percentage_error:97493696.0000,  val_mean_squared_error:1.4476,
# ...............................

# %%
plotter = tfdocs.plots.HistoryPlotter(metric = 'loss', smoothing_std=10)
plotter.plot(size_histories)

# %%
plotter.plot(size_histories)
a = plt.xscale('log')
plt.xlim([5, max(plt.xlim())])
#plt.ylim([0.5, 0.7])
plt.xlabel("Epochs [Log Scale]")
# Out:
# Text(0.5, 0, 'Epochs [Log Scale]')

# %%
plotter.plot(size_histories)
a = plt.xscale('log')
plt.xlim([5, max(plt.xlim())])
#plt.ylim([0.5, 0.7])
plt.xlabel("Epochs [Log Scale]")
# Out:
# Text(0.5, 0, 'Epochs [Log Scale]')

# %%
#plot_history(size_histories['model01'])
#plot_history(size_histories['model02'])
#plot_history(size_histories['model03'])
#plot_history(size_histories['model04'])
#plot_history(size_histories['model05'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-14cb4d6c2f28> in <module>
# ----> 1 plot_history(size_histories['model01'])
#       2 plot_history(size_histories['model02'])
#       3 plot_history(size_histories['model03'])
#       4 plot_history(size_histories['model04'])
#       5 plot_history(size_histories['model05'])
#
# <ipython-input-15-f279da444ed4> in plot_history(model_history)
#     148
#     149 def plot_history(model_history):
# --> 150         plt.plot(model_history.history['accuracy'])
#     151         plt.plot(model_history.history['val_accuracy'])
#     152         plt.title("%s accuracy" %model_history)
#
# KeyError: 'accuracy'

# %%
score = load_model('../model/martin_model01.h5').evaluate(test_X01, test_y01, verbose=3)
print("Test Score:", score[0])
print("Test Accuracy:", score[1])
print("#####")

score = load_model('../model/martin_model02.h5').evaluate(test_X02, test_y02, verbose=3)
print("Test Score:", score[0])
print("Test Accuracy:", score[1])
print("#####")

score = load_model('../model/martin_model03.h5').evaluate(test_X03, test_y03, verbose=3)
print("Test Score:", score[0])
print("Test Accuracy:", score[1])
print("#####")

score = load_model('../model/martin_model04.h5').evaluate(test_X04, test_y04, verbose=3)
print("Test Score:", score[0])
print("Test Accuracy:", score[1])
print("#####")

score = load_model('../model/martin_model05.h5').evaluate(test_X05, test_y05, verbose=3)
print("Test Score:", score[0])
print("Test Accuracy:", score[1])
print("#####")
# Out:
# WARNING:tensorflow:From C:\Users\Lisa\Anaconda3\envs\tf\lib\site-packages\tensorflow_core\python\ops\init_ops.py:97: calling GlorotUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\Users\Lisa\Anaconda3\envs\tf\lib\site-packages\tensorflow_core\python\ops\init_ops.py:97: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Test Score: 0.9479200930375742
# Test Accuracy: 0.54894435
# #####
# Test Score: 0.9561120109124617
# Test Accuracy: 0.5255682
# #####
# Test Score: 0.963270442052321
# Test Accuracy: 0.50852275
# #####
# Test Score: 0.9986639254433768
# Test Accuracy: 0.5057143
# #####
# Test Score: 1.0149496456554958
# Test Accuracy: 0.5285714
# #####
